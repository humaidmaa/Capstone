# %%
# Import libaraies and helper functions

import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsRegressor
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition
import yellowbrick as yb
from yellowbrick.features import Rank1D
from yellowbrick.features import Rank2D
import warnings

# %%
# load the weather and  electricity data 
meter_data1=pd.read_csv("homeA2014.csv",parse_dates=True,index_col='Date & Time')
Meter_data2=pd.read_csv("HomeA-meter2_2014.csv",parse_dates=True,index_col='Date & Time')
Meter_data3=pd.read_csv("HomeA-meter3_2014.csv",parse_dates=True,index_col='Date & Time')
Meter_data4=pd.read_csv("HomeA-meter4_2014.csv",parse_dates=True,index_col='Date & Time')

# %%
#load the first meter data  rows
meter_data1.head()
# Out:
#                      temperature         icon  humidity  visibility summary  \
# Date & Time
# 2014-01-01 00:00:00        16.67  clear-night      0.53        10.0   Clear
# 2014-01-01 01:00:00        16.19  clear-night      0.52        10.0   Clear
# 2014-01-01 02:00:00        15.69  clear-night      0.55        10.0   Clear
# 2014-01-01 03:00:00        15.29  clear-night      0.58        10.0   Clear
# 2014-01-01 04:00:00        15.37  clear-night      0.60        10.0   Clear
#
#                      apparentTemperature  pressure  windSpeed  cloudCover  \
# Date & Time
# 2014-01-01 00:00:00                 3.95   1022.69      11.23        0.00
# 2014-01-01 01:00:00                 4.18   1022.58       9.92        0.02
# 2014-01-01 02:00:00                 4.41   1023.61       8.72        0.00
# 2014-01-01 03:00:00                 4.29   1024.31       8.25        0.00
# 2014-01-01 04:00:00                 5.12   1024.51       7.38        0.06
#
# ...

# %%
Meter_data2.head()
# Out:
#                      use [kW]  gen [kW]  FurnaceHRV [kW]  CellarOutlets [kW]  \
# Date & Time
# 2014-01-01 00:00:00         0         0         0.195338            0.083204
# 2014-01-01 00:30:00         0         0         0.182158            0.036139
# 2014-01-01 01:00:00         0         0         0.134808            0.047034
# 2014-01-01 01:30:00         0         0         0.182125            0.071407
# 2014-01-01 02:00:00         0         0         0.092988            0.014203
#
#                      WashingMachine [kW]  FridgeRange [kW]  \
# Date & Time
# 2014-01-01 00:00:00             0.005686          0.006892
# 2014-01-01 00:30:00             0.005679          0.094138
# 2014-01-01 01:00:00             0.005635          0.014786
# 2014-01-01 01:30:00             0.005672          0.082081
# 2014-01-01 02:00:00             0.005570          0.031901
#
#                      DisposalDishwasher [kW]  KitchenLights [kW]  \
# Date & Time
# ...

# %%
Meter_data3.head()
# Out:
#                      use [kW]  gen [kW]  ElectricRange [kW]  Dryer [kW]  \
# Date & Time
# 2014-01-01 00:00:00         0         0            0.002883    0.005231
# 2014-01-01 00:30:00         0         0            0.003022    0.005441
# 2014-01-01 01:00:00         0         0            0.002979    0.005293
# 2014-01-01 01:30:00         0         0            0.002955    0.005317
# 2014-01-01 02:00:00         0         0            0.003059    0.005368
#
#                      GarageMudroomLights [kW]  DiningRoomOutlets [kW]  \
# Date & Time
# 2014-01-01 00:00:00                  0.013155                       0
# 2014-01-01 00:30:00                  0.012962                       0
# 2014-01-01 01:00:00                  0.013107                       0
# 2014-01-01 01:30:00                  0.012978                       0
# 2014-01-01 02:00:00                  0.012886                       0
#
#                      MudroomOutlets [kW]  MasterBathOutlets [kW]  \
# Date & Time
# ...

# %%
Meter_data4.head()
# Out:
#                      use [kW]  gen [kW]  KitchenDenLights [kW]  \
# Date & Time
# 2014-01-01 00:00:00       0.0       0.0                    0.0
# 2014-01-01 00:15:00       0.0       0.0                    0.0
# 2014-01-01 00:30:00       0.0       0.0                    0.0
# 2014-01-01 00:45:00       0.0       0.0                    0.0
# 2014-01-01 01:00:00       0.0       0.0                    0.0
#
#                      MasterBedBathLights [kW]  MasterOutlets [kW]  \
# Date & Time
# 2014-01-01 00:00:00                       0.0                 0.0
# 2014-01-01 00:15:00                       0.0                 0.0
# 2014-01-01 00:30:00                       0.0                 0.0
# 2014-01-01 00:45:00                       0.0                 0.0
# 2014-01-01 01:00:00                       0.0                 0.0
#
#                      DenOutdoorLights [kW]  DenOutlets [kW]  \
# Date & Time
# 2014-01-01 00:00:00                    0.0              0.0
# ...

# %%
plt.figure(figsize=(10,20))
    plt.figure()
    df.iloc[:,i].plot()
    plt.title(df.columns[i])
plt.tight_layout
